# %%
from enum import Enum
import math

# %%
class protocol(Enum):
    DEFENCE = 0
    ATTACK = 1
    INTERFERENCE = 2

class colour(Enum):
    YELLOW = 0
    BLUE = 1

class starting_position(Enum):
    BACK_LEFT = 0
    BACK_CENTRE = 1
    BACK_RIGHT = 2
    FRONT_LEFT = 3
    FRONT_CENTRE = 4
    FRONT_RIGHT = 5

class robot:
    def __init__(self, starting_position:starting_position, team_colour:colour):
        self.starting_position = starting_position
        self.team_colour = team_colour
        self.current_position = (self.starting_position % 2, self.starting_position/3)
        


def getTeammateProtocol() -> Protocol:...

def protocolSelector(current_protocol:Protocol = None) -> Protocol:
    if current_protocol == None:
        match getTeammateProtocol():
            case protocol.DEFENCE: 
                return protocol.ATTACK
            case protocol.ATTACK:
                return protocol.INTERFERENCE
            case protocol.INTERFERENCE:
                return protocol.ATTACK
            case _:
                match

# %%
def main():
    protocolSelector()
    print('a')

main()
# Out:
# a
